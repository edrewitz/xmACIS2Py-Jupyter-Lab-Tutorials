# %%
'''
In this example we will make a 90-day average temperature summary for the Saint Cloud, MN Regional Airport (KSTC)

We will need to import the plot_average_temperature_summary function from xmacis2py
'''
from xmacis2py import plot_average_temperature_summary

# %%
'''
In this example we will not be changing any optional arguments
Please see other examples for tutorials on optional arguments
'''
plot_average_temperature_summary('KSTC', 90)
# Out:
# Saved KSTC_Past 90 Days.png to f:ACIS Graphics/KSTC/Past 90 Days/Avg T Summary With Running Mean
