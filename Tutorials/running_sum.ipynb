# %%
'''
In this example we will make a 30-Day  precipitation summary for the Riverside Regional Airport in Southern California (KRAL)

We will need to import both our plot_temperature_summary and plot_precipitation_summary functions from xmacis2py
'''
from xmacis2py import plot_precipitation_summary

# %%
'''
In this example we will choose to display the running sum of precipitation. 

We will change the default setting of show_running_sum=False to show_running_sum=True

'''
plot_precipitation_summary('KRAL', 30, show_running_sum=True)
# Out:
# Saved KRAL_Past 30 Days.png to f:ACIS Graphics/KRAL/Past 30 Days/Precipitation Summary With Running Sum
