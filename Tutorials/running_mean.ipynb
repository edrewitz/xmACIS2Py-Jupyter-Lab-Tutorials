# %%
'''
In this example we will make a 90-day temperature summary for John F. Kennedy International Airport (KJFK)

We will need to import the plot_temperature_summary function from xmacis2py
'''
from xmacis2py import plot_temperature_summary

# %%
'''
In this example we will choose to hide the running mean. 

We will change the default setting of show_running_mean=True to show_running_mean=False

'''
plot_temperature_summary('KJFK', 90, show_running_mean=False)
# Out:
# Saved KJFK_Past 90 Days.png to f:ACIS Graphics/KJFK/Past 90 Days/Temperature Summary Without Running Mean
