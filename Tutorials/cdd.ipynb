# %%
'''
In this example we will make a 90-day cooling degree days summary for Brownsville / South Padre Island International Airport (KBRO)

We will need to import the plot_cdd_summary function from xmacis2py
'''
from xmacis2py import plot_cdd_summary

# %%
'''
In this example we will not be changing any optional arguments
Please see other examples for tutorials on optional arguments
'''
plot_cdd_summary('KBRO', 90)
# Out:
# Saved KBRO_Past 90 Days.png to f:ACIS Graphics/KBRO/Past 90 Days/CDD Summary With Running Mean
