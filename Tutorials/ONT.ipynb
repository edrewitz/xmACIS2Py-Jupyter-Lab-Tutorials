# %%
'''
In this example we will make a 90-day minimum temperature summary for Ontario International Airport (KONT)

We will need to import the plot_minimum_temperature_summary function from xmacis2py
'''
from xmacis2py import plot_minimum_temperature_summary

# %%
'''
In this example we will not be changing any optional arguments
Please see other examples for tutorials on optional arguments
'''
plot_minimum_temperature_summary('KONT', 90)
# Out:
# Saved KONT_Past 90 Days.png to f:ACIS Graphics/KONT/Past 90 Days/Min T Summary With Running Mean
