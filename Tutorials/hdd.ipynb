# %%
'''
In this example we will make a 90-day heating degree days summary for the Riverside, CA Regional Airport (KRAL)

We will need to import the plot_hdd_summary function from xmacis2py
'''
from xmacis2py import plot_hdd_summary

# %%
'''
In this example we will not be changing any optional arguments
Please see other examples for tutorials on optional arguments
'''
plot_hdd_summary('KRAL', 90)
# Out:
# Saved KRAL_Past 90 Days.png to f:ACIS Graphics/KRAL/Past 90 Days/HDD Summary With Running Mean
