# %% [markdown]
# # How The El Niño Southern Oscillation Impacts Winter Precipitation Totals
#
# ## Analyzed With xmACIS2Py
#
# ***xmACIS2Py (C) Eric J. Drewitz 2025-2026***
#
# *xmACIS2Py is an open-source Python package that directly interacts with the ACIS2 Web Services API
# combined with a large suite of analysis tools to help analyze xmACIS2 data in Python.*
#
# [xmACIS2Py Documentation](https://pypi.org/project/xmacis2py/)
#
# [xmACIS2Py GitHub Repository](https://github.com/edrewitz/xmACIS2Py)
#
# In this example, we will use xmACIS2Py and Pandas to analyze and plot how the El Niño Southern Oscillation impacts Precipitation across California and Nevada.
#
# In this example, we are downloading the monthly departures from normal (based on the 1991-2020 climate normals)

# %% [markdown]
# ### Imports

# %%
# Imports Needed:
# - xmACIS2Py
# - Matplotlib
# - Pandas
# - NumPy
# - Cartopy
# - os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os

# We need the following from xmACIS2Py:
# - analysis module (Consists of all xmACIS2Py Analysis Tools)
# - get_multi_station_departures client function - Downloads and returns a Pandas.DataFrame and/or CSV file of the ACIS2 Data.
# - multi_station_meta client function - Downloads and returns a Pandas.DataFrame and/or CSV file of the ACIS2 Meta-Data.
from xmacis2py import(
    analysis,
    get_multi_station_departures,
    multi_station_meta
)

# %% [markdown]
# ### Downloading Our Data

# %%
# List of ASOS Stations across California and Nevada

stations = [
    # --- California ---
    "KACV","KAPC","KAVX","KBFL","KBUR","KCCR","KCIC","KCMA","KCRQ","KDAG",
    "KEDU","KEED","KEKA","KEMT","KFAT","KFUL","KHAF","KHHR","KHJO","KHMT",
    "KHWD","KIPL","KIZA","KLAX","KLVK","KMAE","KMCC","KMCE","KMER","KMHR",
    "KMHV","KMOD","KMRY","KMYF","KMYV","KNFG","KNID","KNKX","KNLC","KNTD",
    "KNUQ","KOAK","KONT","KOVE","KOXR","KPAO","KPMD","KPRB","KPSP","KRAL",
    "KRDD","KRHV","KRIV","KSAC","KSAN","KSBA","KSBD","KSCK","KSFO","KSIY",
    "KSMF","KSMO","KSNA","KSQL","KSTS","KSUU","KTOA","KTRK","KTVL","KUKI",
    "KVBG","KVCV","KVNY","KWJF",

    # --- Nevada ---
    "KBAM","KBTY","KCXP","KEKO","KELY","KHND","KHTH","KINS","KLAS","KLOL",
    "KLSV","KMMH","KNFL","KOWY","KRNO","KTPH","KWMC"
]

# %%
# Using xmACIS2Py to retrieve all the available data in the period between 1981-01-01 and 2025-12-31
get_multi_station_departures(stations,
                            interval='monthly',
                            start_date='1981-01-01',
                            end_date='2025-12-31',
                            to_csv=True,
                            return_pandas_df=False)
# Out:
# KACV Data Saved: XMACIS2 DEPARTURES/MONTHLY/KACV.csv
# KAPC Data Saved: XMACIS2 DEPARTURES/MONTHLY/KAPC.csv
# KAVX Data Saved: XMACIS2 DEPARTURES/MONTHLY/KAVX.csv
# KBFL Data Saved: XMACIS2 DEPARTURES/MONTHLY/KBFL.csv
# KBUR Data Saved: XMACIS2 DEPARTURES/MONTHLY/KBUR.csv
# KCCR Data Saved: XMACIS2 DEPARTURES/MONTHLY/KCCR.csv
# KCIC Data Saved: XMACIS2 DEPARTURES/MONTHLY/KCIC.csv
# KCMA Data Saved: XMACIS2 DEPARTURES/MONTHLY/KCMA.csv
# KCRQ Data Saved: XMACIS2 DEPARTURES/MONTHLY/KCRQ.csv
# KDAG Data Saved: XMACIS2 DEPARTURES/MONTHLY/KDAG.csv
# KEDU not found in database. Skipping...
# KEED Data Saved: XMACIS2 DEPARTURES/MONTHLY/KEED.csv
# KEKA Data Saved: XMACIS2 DEPARTURES/MONTHLY/KEKA.csv
# KEMT not found in database. Skipping...
# KFAT Data Saved: XMACIS2 DEPARTURES/MONTHLY/KFAT.csv
# KFUL Data Saved: XMACIS2 DEPARTURES/MONTHLY/KFUL.csv
# KHAF not found in database. Skipping...
# KHHR Data Saved: XMACIS2 DEPARTURES/MONTHLY/KHHR.csv
# KHJO Data Saved: XMACIS2 DEPARTURES/MONTHLY/KHJO.csv
# KHMT not found in database. Skipping...
# KHWD Data Saved: XMACIS2 DEPARTURES/MONTHLY/KHWD.csv
# KIPL Data Saved: XMACIS2 DEPARTURES/MONTHLY/KIPL.csv
# KIZA not found in database. Skipping...
# KLAX Data Saved: XMACIS2 DEPARTURES/MONTHLY/KLAX.csv
# KLVK Data Saved: XMACIS2 DEPARTURES/MONTHLY/KLVK.csv
# KMAE Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMAE.csv
# KMCC Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMCC.csv
# KMCE Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMCE.csv
# KMER Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMER.csv
# KMHR Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMHR.csv
# KMHV not found in database. Skipping...
# KMOD Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMOD.csv
# KMRY Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMRY.csv
# KMYF Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMYF.csv
# KMYV Data Saved: XMACIS2 DEPARTURES/MONTHLY/KMYV.csv
# KNFG Data Saved: XMACIS2 DEPARTURES/MONTHLY/KNFG.csv
# KNID Data Saved: XMACIS2 DEPARTURES/MONTHLY/KNID.csv
# KNKX Data Saved: XMACIS2 DEPARTURES/MONTHLY/KNKX.csv
# KNLC Data Saved: XMACIS2 DEPARTURES/MONTHLY/KNLC.csv
# KNTD Data Saved: XMACIS2 DEPARTURES/MONTHLY/KNTD.csv
# KNUQ Data Saved: XMACIS2 DEPARTURES/MONTHLY/KNUQ.csv
# KOAK Data Saved: XMACIS2 DEPARTURES/MONTHLY/KOAK.csv
# KONT Data Saved: XMACIS2 DEPARTURES/MONTHLY/KONT.csv
# KOVE Data Saved: XMACIS2 DEPARTURES/MONTHLY/KOVE.csv
# KOXR Data Saved: XMACIS2 DEPARTURES/MONTHLY/KOXR.csv
# KPAO not found in database. Skipping...
# KPMD Data Saved: XMACIS2 DEPARTURES/MONTHLY/KPMD.csv
# KPRB Data Saved: XMACIS2 DEPARTURES/MONTHLY/KPRB.csv
# KPSP Data Saved: XMACIS2 DEPARTURES/MONTHLY/KPSP.csv
# KRAL Data Saved: XMACIS2 DEPARTURES/MONTHLY/KRAL.csv
# KRDD Data Saved: XMACIS2 DEPARTURES/MONTHLY/KRDD.csv
# KRHV not found in database. Skipping...
# KRIV Data Saved: XMACIS2 DEPARTURES/MONTHLY/KRIV.csv
# KSAC Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSAC.csv
# KSAN Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSAN.csv
# KSBA Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSBA.csv
# KSBD Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSBD.csv
# KSCK Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSCK.csv
# KSFO Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSFO.csv
# KSIY Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSIY.csv
# KSMF Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSMF.csv
# KSMO Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSMO.csv
# KSNA Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSNA.csv
# KSQL not found in database. Skipping...
# KSTS Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSTS.csv
# KSUU Data Saved: XMACIS2 DEPARTURES/MONTHLY/KSUU.csv
# KTOA not found in database. Skipping...
# KTRK Data Saved: XMACIS2 DEPARTURES/MONTHLY/KTRK.csv
# KTVL Data Saved: XMACIS2 DEPARTURES/MONTHLY/KTVL.csv
# KUKI Data Saved: XMACIS2 DEPARTURES/MONTHLY/KUKI.csv
# KVBG Data Saved: XMACIS2 DEPARTURES/MONTHLY/KVBG.csv
# KVCV Data Saved: XMACIS2 DEPARTURES/MONTHLY/KVCV.csv
# KVNY Data Saved: XMACIS2 DEPARTURES/MONTHLY/KVNY.csv
# KWJF Data Saved: XMACIS2 DEPARTURES/MONTHLY/KWJF.csv
# KBAM Data Saved: XMACIS2 DEPARTURES/MONTHLY/KBAM.csv
# KBTY not found in database. Skipping...
# KCXP not found in database. Skipping...
# KEKO Data Saved: XMACIS2 DEPARTURES/MONTHLY/KEKO.csv
# KELY Data Saved: XMACIS2 DEPARTURES/MONTHLY/KELY.csv
# KHND Data Saved: XMACIS2 DEPARTURES/MONTHLY/KHND.csv
# KHTH not found in database. Skipping...
# KINS Data Saved: XMACIS2 DEPARTURES/MONTHLY/KINS.csv
# KLAS Data Saved: XMACIS2 DEPARTURES/MONTHLY/KLAS.csv
# KLOL Data Saved: XMACIS2 DEPARTURES/MONTHLY/KLOL.csv
# KLSV Data Saved: XMACIS2 DEPARTURES/MONTHLY/KLSV.csv
# KMMH not found in database. Skipping...
# KNFL Data Saved: XMACIS2 DEPARTURES/MONTHLY/KNFL.csv
# KOWY not found in database. Skipping...
# KRNO Data Saved: XMACIS2 DEPARTURES/MONTHLY/KRNO.csv
# KTPH Data Saved: XMACIS2 DEPARTURES/MONTHLY/KTPH.csv
# KWMC Data Saved: XMACIS2 DEPARTURES/MONTHLY/KWMC.csv

# %%
# We are now going to extract all the station IDs for the stations that have data.
# The filename is the station ID so we need to extract that and remove the .csv file extension

stations_downloaded = []
for file in os.listdir(f"XMACIS2 DEPARTURES/MONTHLY"):
    filename = os.path.basename(f"XMACIS2 DEPARTURES/MONTHLY/{file}")
    filename = f"{filename[0:4]}"
    stations_downloaded.append(filename)

# %%
# We need the meta data for each station
# We need the latitude and longitude from this meta data

multi_station_meta(stations_downloaded,
                   to_csv=True,
                   return_pandas_df=False)
# Out:
# KACV.csv saved to XMACIS2 META
# KAPC.csv saved to XMACIS2 META
# KAVX.csv saved to XMACIS2 META
# KBAM.csv saved to XMACIS2 META
# KBFL.csv saved to XMACIS2 META
# KBUR.csv saved to XMACIS2 META
# KCCR.csv saved to XMACIS2 META
# KCIC.csv saved to XMACIS2 META
# KCMA.csv saved to XMACIS2 META
# KCRQ.csv saved to XMACIS2 META
# KDAG.csv saved to XMACIS2 META
# KEED.csv saved to XMACIS2 META
# KEKA.csv saved to XMACIS2 META
# KEKO.csv saved to XMACIS2 META
# KELY.csv saved to XMACIS2 META
# KFAT.csv saved to XMACIS2 META
# KFUL.csv saved to XMACIS2 META
# KHHR.csv saved to XMACIS2 META
# KHJO.csv saved to XMACIS2 META
# KHND.csv saved to XMACIS2 META
# KHWD.csv saved to XMACIS2 META
# KINS.csv saved to XMACIS2 META
# KIPL.csv saved to XMACIS2 META
# KLAS.csv saved to XMACIS2 META
# KLAX.csv saved to XMACIS2 META
# KLOL.csv saved to XMACIS2 META
# KLSV.csv saved to XMACIS2 META
# KLVK.csv saved to XMACIS2 META
# KMAE.csv saved to XMACIS2 META
# KMCC.csv saved to XMACIS2 META
# KMCE.csv saved to XMACIS2 META
# KMER.csv saved to XMACIS2 META
# KMHR.csv saved to XMACIS2 META
# KMOD.csv saved to XMACIS2 META
# KMRY.csv saved to XMACIS2 META
# KMYF.csv saved to XMACIS2 META
# KMYV.csv saved to XMACIS2 META
# KNFG.csv saved to XMACIS2 META
# KNFL.csv saved to XMACIS2 META
# KNID.csv saved to XMACIS2 META
# KNKX.csv saved to XMACIS2 META
# KNLC.csv saved to XMACIS2 META
# KNTD.csv saved to XMACIS2 META
# KNUQ.csv saved to XMACIS2 META
# KOAK.csv saved to XMACIS2 META
# KONT.csv saved to XMACIS2 META
# KOVE.csv saved to XMACIS2 META
# KOXR.csv saved to XMACIS2 META
# KPMD.csv saved to XMACIS2 META
# KPRB.csv saved to XMACIS2 META
# KPSP.csv saved to XMACIS2 META
# KRAL.csv saved to XMACIS2 META
# KRDD.csv saved to XMACIS2 META
# KRIV.csv saved to XMACIS2 META
# KRNO.csv saved to XMACIS2 META
# KSAC.csv saved to XMACIS2 META
# KSAN.csv saved to XMACIS2 META
# KSBA.csv saved to XMACIS2 META
# KSBD.csv saved to XMACIS2 META
# KSCK.csv saved to XMACIS2 META
# KSFO.csv saved to XMACIS2 META
# KSIY.csv saved to XMACIS2 META
# KSMF.csv saved to XMACIS2 META
# KSMO.csv saved to XMACIS2 META
# KSNA.csv saved to XMACIS2 META
# KSTS.csv saved to XMACIS2 META
# KSUU.csv saved to XMACIS2 META
# KTPH.csv saved to XMACIS2 META
# KTRK.csv saved to XMACIS2 META
# KTVL.csv saved to XMACIS2 META
# KUKI.csv saved to XMACIS2 META
# KVBG.csv saved to XMACIS2 META
# KVCV.csv saved to XMACIS2 META
# KVNY.csv saved to XMACIS2 META
# KWJF.csv saved to XMACIS2 META
# KWMC.csv saved to XMACIS2 META

# %% [markdown]
# ### Organzing Our Meta-Data
#
# Here, we will organize our meta-data into one Pandas.DataFrame by doing the following:
#
# 1) Use `pd.read_csv()` to create a Pandas.DataFrame for all CSV files in the XMACIS META Folder
# 2) Use `pd.concat()` to combine the list of Pandas.DataFrames into one Pandas.DataFrame

# %%
meta_data_list = []
for file in os.listdir(f"XMACIS2 META"):
    meta = pd.read_csv(f"XMACIS2 META/{file}")
    meta_data_list.append(meta)

meta = pd.concat(meta_data_list, ignore_index=True)

# %%
# Rename column "station" to "Station ID"
meta = meta.rename(columns={"station":"Station ID"})

# %%
# Meta-Data (Pandas.DataFrame)
meta
# Out:
#    Station ID                             Station Name  \
# 0         402                         ARCATA EUREKA AP
# 1        APC                       NAPA COUNTY AIRPORT
# 2        AVX                        AVALON CATALINA AP
# 3        B23                       BATTLE MOUNTAIN 4SE
# 4        BFL                            BAKERSFIELD AP
# ..        ...                                      ...
# 71       7239                           VANDENBERG AFB
# 72       KVCV  VICTORVILLE SOUTHERN CALIFORNIA INTL AP
# 73       KVNY                              VAN NUYS AP
# 74       WJF                                 LANCASTER
# 75       WMC                        WINNEMUCCA AIRPORT
#
#     Station Elevation (ft) State  Latitude  Longitude
# 0                    211.0    CA  40.97844 -124.10479
# 1                     16.0    CA  38.20750 -122.28041
# 2                   1565.0    CA  33.40419 -118.41456
# 3                   4505.0    NV  40.61180 -116.89170
# 4                    490.0    CA  35.43424 -119.05524
# ..                     ...   ...       ...        ...
# 71                   369.0    CA  34.71667 -120.56667
# 72                  2885.0    CA  34.58333 -117.38333
# 73                   785.0    CA  34.21214 -118.49146
# 74                  2338.0    CA  34.74121 -118.21255
# 75                  4300.0    NV  40.90178 -117.80812
#
# [76 rows x 6 columns]

# %% [markdown]
# ### Renaming our Files to Match the IDs in the Meta-Data

# %%
for station, station_id in zip(stations_downloaded, meta['Station ID']):
    os.replace(f"XMACIS2 DEPARTURES/MONTHLY/{station}.csv", f"XMACIS2 DEPARTURES/MONTHLY/{station_id}.csv")

# %% [markdown]
# ### Choosing Our Analogs
#
# In this next section, we will choose our Analogs for the Top 5 El Niño and Top 5 La Niña winter (DJF) periods since 1981.
#
# ***Oceanic Niño Index (NOAA)***
#
#
# <img src="https://github.com/edrewitz/xmACIS2Py-Jupyter-Lab-Tutorials/blob/main/diagrams/oni%20index.png?raw=true" width="400" height="300">

# %% [markdown]
# ***We will Filter Analog Years for the DJF period for the top 5 El Nino Years and top 5 La Nina Years***
#
# ***Top 5 El Nino Years (DJF)***: 1) 2016 = 2.6, 2) 1983 = 2.2, 3) 1998 = 2.2, 4) 2024 = 1.9, 5) 1992 = 1.7.
#
# ***Top 5 La Nina Years (DJF)***: 1) 1989 = -1.7, 2) 2000 = -1.7, 3) 2008 = -1.6, 4) 1999 = -1.5, 5) 2011 = -1.3.

# %% [markdown]
# ### Filtering Analogs
#
# Here, we filter our El Niño and La Niña Analogs

# %%
for station in meta['Station ID']:
    # El Niño
    analysis.filter_analog_years(station,
                                 [(2015, 12), (2016, 1), (2016, 2),
                                 (1982, 12), (1983, 1), (1983, 2),
                                 (1997, 12), (1998, 1), (1998, 2),
                                 (2023, 12), (2024, 1), (2024, 2),
                                 (1991, 12), (1992, 1), (1992, 2)],
                                 input_path=f"XMACIS2 DEPARTURES/MONTHLY/{station}.csv",
                                 to_csv=True,
                                 output_path=f"XMACIS2 ANALOGS/El Nino",
                                 return_pandas_df=False)



    # La Niña
    analysis.filter_analog_years(station,
                                 [(1988, 12), (1989, 1), (1989, 2),
                                 (1999, 12), (2000, 1), (2000, 2),
                                 (2007, 12), (2008, 1), (2008, 2),
                                 (1998, 12), (1999, 1), (1999, 2),
                                 (2010, 12), (2011, 1), (2011, 2)],
                                 input_path=f"XMACIS2 DEPARTURES/MONTHLY/{station}.csv",
                                 to_csv=True,
                                 output_path=f"XMACIS2 ANALOGS/La Nina",
                                 return_pandas_df=False)

# %% [markdown]
# ### Calculate Weighted Mean Anomalies
#
# ***El Nino Years Weights***: 2 for 2016; 1 for 1983; 1 for 1998; 1 for 2024; 1.5 for 1992.
#
# ***La Nina Years Weights***: 2 for 1989; 1 for 2000; 1 for 2008; 1 for 1999; 1.5 for 2011.

# %%
try:
    os.makedirs(f"El Nino Means")
except Exception as e:
    pass

try:
    os.makedirs(f"La Nina Means")
except Exception as e:
    pass

for station in meta['Station ID']:
    nino = pd.read_csv(f"XMACIS2 ANALOGS/EL NINO/{station}.csv")
    nino['Station'] = station

    nino['El Nino Precip Mean'] = analysis.analog_weighted_mean(nino, 
                                                 'Precipitation Departure',
                                                 [2, 1, 1, 1, 1.5])

    nino.to_csv(f"El Nino Means/{station}.csv")

for station in meta['Station ID']:
    nina = pd.read_csv(f"XMACIS2 ANALOGS/LA NINA/{station}.csv")
    nina['Station'] = station

    nina['La Nina Precip Mean'] = analysis.analog_weighted_mean(nina, 
                                                 'Precipitation Departure',
                                                 [2, 1, 1, 1, 1.5])

    nina.to_csv(f"La Nina Means/{station}.csv")

# %% [markdown]
# ### Merge Pandas.DataFrames (Meta-Data & Anomalies)
#
# Here, we will create a new Pandas.DataFrame that has the following:
#
# 1) Station ID
# 2) Latitude
# 3) Longitude
# 4) Anomaly

# %%
nino_anoms = []
for station in meta['Station ID']:
    df = pd.read_csv(f"El Nino Means/{station}.csv")
    nino_anom = df['El Nino Precip Mean'][0]
    nino_anoms.append(nino_anom)

el_nino = pd.DataFrame({
    "Station ID": meta['Station ID'],
    "anomaly": nino_anoms
})

# %%
nina_anoms = []
for station in meta['Station ID']:
    df = pd.read_csv(f"La Nina Means/{station}.csv")
    nina_anom = df['La Nina Precip Mean'][0]
    nina_anoms.append(nina_anom)

la_nina = pd.DataFrame({
    "Station ID": meta['Station ID'],
    "anomaly": nina_anoms
})

# %%
el_nino
# Out:
#    Station ID   anomaly
# 0         402       NaN
# 1        APC        NaN
# 2        AVX        NaN
# 3        B23  -0.152000
# 4        BFL   0.377949
# ..        ...       ...
# 71       7239       NaN
# 72       KVCV       NaN
# 73       KVNY       NaN
# 74       WJF        NaN
# 75       WMC   0.047333
#
# [76 rows x 2 columns]

# %%
la_nina
# Out:
#    Station ID   anomaly
# 0         402       NaN
# 1        APC        NaN
# 2        AVX        NaN
# 3        B23  -0.170667
# 4        BFL   0.027179
# ..        ...       ...
# 71       7239       NaN
# 72       KVCV       NaN
# 73       KVNY       NaN
# 74       WJF        NaN
# 75       WMC  -0.157333
#
# [76 rows x 2 columns]

# %%
el_nino = el_nino.merge(
    meta[["Station ID", "Latitude", "Longitude"]],
    on="Station ID",
    how="left"
)

# %%
el_nino = el_nino.dropna()

# %%
el_nino
# Out:
#    Station ID   anomaly  Latitude  Longitude
# 3        B23  -0.152000  40.61180 -116.89170
# 4        BFL   0.377949  35.43424 -119.05524
# 10       DAG   0.309487  34.85371 -116.78702
# 11       EED   0.174000  34.76783 -114.61842
# 12       EKA   1.944872  40.80970 -124.16020
# 13       EKO   0.163333  40.82402 -115.78635
# 14       ELY   0.202667  39.29537 -114.84666
# 15        432  0.843846  36.77999 -119.72016
# 23       LAS  -0.063590  36.07190 -115.16343
# 50       PRB   1.244000  35.66936 -120.62918
# 53        473  1.530667  40.51462 -122.29773
# 55       RNO  -0.106000  39.50769 -119.76829
# 79       WMC   0.047333  40.90178 -117.80812

# %%
la_nina = la_nina.merge(
    meta[["Station ID", "Latitude", "Longitude"]],
    on="Station ID",
    how="left"
)

# %%
la_nina = la_nina.dropna()

# %%
la_nina
# Out:
#    Station ID   anomaly  Latitude  Longitude
# 3        B23  -0.170667  40.61180 -116.89170
# 4        BFL   0.027179  35.43424 -119.05524
# 10       DAG  -0.180000  34.85371 -116.78702
# 11       EED  -0.330000  34.76783 -114.61842
# 12       EKA  -1.103590  40.80970 -124.16020
# 13       EKO  -0.121538  40.82402 -115.78635
# 14       ELY   0.058718  39.29537 -114.84666
# 15        432  0.283846  36.77999 -119.72016
# 23       LAS  -0.251282  36.07190 -115.16343
# 50       PRB  -0.232821  35.66936 -120.62918
# 53        473 -2.067500  40.51462 -122.29773
# 55       RNO  -0.170000  39.50769 -119.76829
# 79       WMC  -0.157333  40.90178 -117.80812

# %% [markdown]
# ### Plot Our Data

# %%
# Plots El Niño Analogs for the stations that have data for the queried analog periods

fig = plt.figure(figsize=(12,12))
box = dict(boxstyle='round', facecolor='lightsteelblue')
ax = fig.add_subplot(1,1,1, projection=ccrs.PlateCarree())
# Set our bounds and data coordinate reference system
ax.set_extent([-125, -114, 32.5, 42.1], ccrs.PlateCarree())

# Add coastlines for the outline of the coasts
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.75, zorder=9)

# Add our country borders
ax.add_feature(cfeature.BORDERS, linestyle='-', zorder=2)
ax.add_feature(cfeature.STATES, linestyle='-', zorder=2)
ax.add_feature(cfeature.LAND, facecolor='beige', zorder=1)
ax.add_feature(cfeature.OCEAN, facecolor='lightskyblue', zorder=1)
ax.set_title(f"El Niño Analogs", fontsize=14, fontweight='bold', loc='left', bbox=box)
ax.set_title(f"Years: 2016, 1983, 1998, 2024, 1992", fontsize=10, fontweight='bold', loc='right', bbox=box)
ax.text(0.01, 0, f"Plot Created by Eric J. Drewitz - Powered by xmacis2py", fontsize=7, zorder=10, fontweight='bold', transform=ax.transAxes, bbox=box)

# Create our colormap
cmap = mcolors.LinearSegmentedColormap.from_list("average temperature", ["saddlebrown", "lightgray", "darkgreen"])

sc = ax.scatter(el_nino['Longitude'], el_nino['Latitude'], c=el_nino['anomaly'], cmap=cmap,
                norm=mcolors.Normalize(vmin=-0.5, vmax=0.5, clip=True))
cbar = fig.colorbar(sc, ax=ax, extend='both', pad=0.01, aspect=50, shrink=0.775)
cbar.set_ticks(np.arange(-0.5, 0.6, 0.1))
cbar.set_label("Precipitation Anomaly (Inches)", fontweight='bold', fontsize=10)

# %%
# Plots La Niña Analogs for the stations that have data for the queried analog periods

fig = plt.figure(figsize=(12,12))
box = dict(boxstyle='round', facecolor='lightsteelblue')
ax = fig.add_subplot(1,1,1, projection=ccrs.PlateCarree())
# Set our bounds and data coordinate reference system
ax.set_extent([-125, -114, 32.5, 42.1], ccrs.PlateCarree())

# Add coastlines for the outline of the coasts
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.75, zorder=9)

# Add our country borders
ax.add_feature(cfeature.BORDERS, linestyle='-', zorder=2)
ax.add_feature(cfeature.STATES, linestyle='-', zorder=2)
ax.add_feature(cfeature.LAND, facecolor='beige', zorder=1)
ax.add_feature(cfeature.OCEAN, facecolor='lightskyblue', zorder=1)
ax.set_title(f"La Niña Analogs", fontsize=14, fontweight='bold', loc='left', bbox=box)
ax.set_title(f"Years: 1989, 2000, 2008, 1999, 2011", fontsize=10, fontweight='bold', loc='right', bbox=box)
ax.text(0.01, 0, f"Plot Created by Eric J. Drewitz - Powered by xmacis2py", fontsize=7, zorder=10, fontweight='bold', transform=ax.transAxes, bbox=box)

# Create our colormap
cmap = mcolors.LinearSegmentedColormap.from_list("average temperature", ["saddlebrown", "lightgray", "darkgreen"])

sc = ax.scatter(la_nina['Longitude'], la_nina['Latitude'], c=la_nina['anomaly'], cmap=cmap,
                norm=mcolors.Normalize(vmin=-0.5, vmax=0.5, clip=True))
cbar = fig.colorbar(sc, ax=ax, extend='both', pad=0.01, aspect=50, shrink=0.775)
cbar.set_ticks(np.arange(-0.5, 0.6, 0.1))
cbar.set_label("Precipitation Anomaly (Inches)", fontweight='bold', fontsize=10)
