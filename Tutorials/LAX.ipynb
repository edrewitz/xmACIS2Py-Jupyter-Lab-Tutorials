# %%
'''
In this example we will make a 90-day maximum temperature summary for Los Angeles International Airport (KLAX)

We will need to import the plot_maximum_temperature_summary function from xmacis2py
'''
from xmacis2py import plot_maximum_temperature_summary

# %%
'''
In this example we will not be changing any optional arguments
Please see other examples for tutorials on optional arguments
'''
plot_maximum_temperature_summary('KLAX', 90)
# Out:
# Saved KLAX_Past 90 Days.png to f:ACIS Graphics/KLAX/Past 90 Days/Max T Summary With Running Mean
